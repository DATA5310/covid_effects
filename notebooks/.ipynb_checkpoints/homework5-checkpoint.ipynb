# %% [markdown]
# ## Activity 1
#
# Identify a data set that you will be using. Provide a link to the data set.
# Describe anything in the data that will need to be cleaned up or modified in some way before you will be able to make graphs from it.
# What additional information could be useful to supplement this data set? Describe at least three variables beyond what is included in the data set that could be valuable to find and merge with this data.

# %% [markdown]
# In this assignment, we want to visualize the impacts that COVID-19 have on the occurrences of other diseases, such as cancer, heart diseases, respiratory diseases, etc... We've chosen the "Underlying Cause of Death, 2018-2022, Single Race" dataset to explore deaths and population counts in the US during 2018 to 2022. This is the link to the dataset: https://wonder.cdc.gov/ucd-icd10-expanded.html. With this dataset, we're able to do a minimal amount of data cleaning and preprocessing, including removing missing values. We also made sure that the columns included are of the correct data types (strings and integers), to aid in creating the visualizations.
#
# To supplement the dataset on death causes of U.S. residents from 2018 to 2022, additional information that could enhance analysis of COVID-19's impact on other diseases includes demographic factors, healthcare access, and vaccination data. We'd like to merge our current dataset with the "US 2023 Chronic Disease Indicator" dataset. This is the link to the dataset: https://data.cdc.gov/Chronic-Disease-Indicators/U-S-Chronic-Disease-Indicators-CDI-2023-Release/g4ie-h725/about_data
#
# Firstly, incorporating demographic variables such as age, gender, race, and socioeconomic status would provide insights into how these factors may influence both COVID-19 outcomes and the prevalence of other chronic diseases. Secondly, healthcare access, such as the percentage of individuals with health insurance, would be crucial in understanding how the pandemic may have affected treatment for other diseases. Lastly, including vaccination status data could help analyze the relationship between COVID-19 vaccination rates and mortality or morbidity from other conditions. Merging these variables with the existing dataset could yield a comprehensive view of the interplay between COVID-19 and chronic disease mortality rates.

# %% [markdown]
# ## Activity 2
#
# Each member of the group should make a graph looking at something from the data set. Include these graphs, and label who created each graph. For the moment, this is completely open-ended. We're not trying to do anything specific yet, just starting to get used to loading this data into R and working with it.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import chardet

# %%
underlying_cause_of_death = "../datasets/raw/Underlying_Cause_of_Death_2022.csv"
underlying_cause_of_death_cols = [
    "Year",
    "Cause of death",
    "Cause of death Code",
    "Deaths",
    "Population",
    "Crude Rate",
]
underlying_cause_of_death_dtype = {
    # capital I or capital F for nullable types
    "Year": "category",
    "Cause of death": "category",
    "Cause of death Code": "category",
    "Deaths": "Int32",
    "Population": "Int32",
    "Crude Rate": "Float32",
}

# somehow it's not UTF-8 encoded
with open(underlying_cause_of_death, "rb") as file:
    raw = file.read()
    encoding = chardet.detect(raw)["encoding"]

df = pd.read_csv(
    underlying_cause_of_death,
    encoding=encoding,
    usecols=underlying_cause_of_death_cols,
    dtype=underlying_cause_of_death_dtype,
    na_values=["Unreliable"],
)

top_5_causes_2020 = (
    df[df["Year"] == "2020"]
    .groupby("Cause of death", observed=True)["Deaths"]
    .sum()
    .reset_index()
    .sort_values("Deaths", ascending=False)
    .head(5)
)

print(top_5_causes_2020)

# plt.figure(figsize=(12, 6))
# sns.barplot(
#     data=top_5_causes_2020,
#     x="Cause of death",
#     y="Deaths",
# )

plt.figure(figsize=(12, 6))
plt.bar(
    top_5_causes_2020["Cause of death"], top_5_causes_2020["Deaths"], color="skyblue"
)
plt.title("Top 5 Causes of Death in 2020")
plt.xlabel("Cause of Death")
plt.ylabel("Number of Deaths")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
#                                         Cause of death  Deaths
# 250                                           COVID-19  350831
# 181                      Atherosclerotic heart disease  169855
# 243  Bronchus or lung, unspecified - Malignant neop...  132294
# 105                     Alzheimer disease, unspecified  127247
# 360  Chronic obstructive pulmonary disease, unspeci...  115004

# %%
data_heart = df[df['Cause of death'].str.contains('heart', case=False, na=False)]
data_heart.head()
# Out:
#      Year                                     Cause of death  \
# 222  2018                        Heart - Malignant neoplasms
# 402  2018                           Heart - Benign neoplasms
# 804  2018  Rheumatic fever without mention of heart invol...
# 822  2018               Rheumatic heart disease, unspecified
# 824  2018  Hypertensive heart disease with (congestive) h...
#
#     Cause of death Code  Deaths  Population  Crude Rate
# 222               C38.0      60   327167434         0.0
# 402               D15.1      27   327167434         0.0
# 804                 I00      11   327167434        <NA>
# 822               I09.9     172   327167434         0.1
# 824               I11.0   20223   327167434         6.2

# %%
data_heart.loc[:, 'Crude Rate'] = pd.to_numeric(data_heart['Crude Rate'], errors='coerce')
average_crude_rate_per_year = data_heart.groupby('Year')['Crude Rate'].mean().reset_index()
# Out:
# /var/folders/tc/t9c_fvpn08jbwz38bdj660vm0000gn/T/ipykernel_40766/2214504801.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_crude_rate_per_year = data_heart.groupby('Year')['Crude Rate'].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))

colors = ['#4C72B0', '#55A868', '#C44E52', '#8172B2', '#CCB974']
bars = plt.bar(
    average_crude_rate_per_year['Year'],
    average_crude_rate_per_year['Crude Rate'],
    color=colors
)

# Data labels on top of each bar
for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f'{bar.get_height():.2f}',
        ha='center',
        va='bottom',
        fontsize=10
    )

# Custom legend
plt.legend(
    bars, 
    [int(year) for year in average_crude_rate_per_year['Year']], 
    title="Year",
    bbox_to_anchor=(1, 1),
    loc='upper left'
)

plt.xlabel("Year")
plt.ylabel("Average Death Rate")
plt.title("Death rate per 100,000 persons in USA from heart related problems (2018-2022)")

plt.figtext(0.75,- 0.05, "Created by Lakshit Gupta", ha="center", fontsize=10, color="gray")
plt.tight_layout()
plt.show()

# %%
covid = df[df["Cause of death Code"] == "U07.1"]
 
plt.figure(figsize=(10, 6))
 
plt.bar(covid['Year'], covid['Deaths'], color='skyblue')
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.title('COVID-19 Deaths in the U.S. (2020-2022)')
plt.xticks(covid['Year'])
 
plt.figtext(0.75, -0.05, "Created by Ponnu Soman", ha="center", fontsize=10, color="gray")
plt.tight_layout()
plt.show()

# %%
keycodes = r"I00|I01|I02|I03|I04|I05|I06|I07|I08|I09|I11|I13|I20|I21|I22|I23|I24|I25|I26|I27|I28|I29|I30|I31|I32|I33|I34|I35|I36|I37|I38|I39|I40|I41|I42|I43|I44|I45|I46|I47|I48|I49|I50|I51"

heart_df = df[df['Cause of death Code'].str.contains(keycodes, case=False, na=False)]

selected_diseases = ['I21.9', 'I25.1', 'I50.0', 'I25.0']
disease_names = ['Heart Attack', 'Coronary Artery Disease', 'Congestive Heart Failure', 'Chronic Ischemic Heart Disease']  # Corresponding names

disease_mapping = dict(zip(selected_diseases, disease_names))

filtered_df = heart_df[heart_df['Cause of death Code'].isin(selected_diseases)]

pivot_data = filtered_df.pivot_table(index='Year', columns='Cause of death Code', values='Deaths', aggfunc='sum')

pivot_data.columns = [disease_mapping[col] for col in pivot_data.columns]

plt.figure(figsize=(12, 6))
sns.heatmap(pivot_data, cmap='YlOrBr', annot=True, fmt='d', cbar_kws={'label': 'Number of Deaths'})
plt.title('Heatmap of Deaths from Top Heart Diseases Over Time')
plt.xlabel('Cause of Death')
plt.ylabel('Year')
plt.text(1.2, -0.60, 'Created by Duong Le', fontsize=10, color='Gray', 
         ha='right', transform=plt.gca().transAxes)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
